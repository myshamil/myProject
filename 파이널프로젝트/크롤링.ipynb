# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from urllib.request import urlopen
from selenium.webdriver.common.keys import Keys
import html5lib
import time

# %%
#제목 검색을 위한 리스트 가져오기 
data = pd.read_excel("moviedata.xlsx")
inp = data["영화명"]
inp
# Out:
# 0                     카오산 탱고
# 1                         욕창
# 2                     바다로 가자
# 3                       국도극장
# 4                레미: 집 없는 아이
#                 ...
# 8233                 다운 바이 로
# 8234                  일트로바토레
# 8235                  워터 릴리스
# 8236              람메르무어의 루치아
# 8237    닉슨인 차이나(뉴욕메트로폴리탄오페라)
# Name: 영화명, Length: 8238, dtype: object

# %%
driver = webdriver.Chrome('chromedriver')
driver.get("https://pedia.watcha.com/ko-KR")
driver.implicitly_wait(5)
#제목 검색->for문
elem = driver.find_element_by_id('global_search_input')
elem.send_keys(inp[22])
elem.send_keys(Keys.RETURN)
driver.implicitly_wait(3)
#영화선택
driver.find_element_by_xpath('//*[@id="root"]/div/div[1]/section/section/section[1]/div[2]/div[1]/div/div/div/ul/li/a').click()
#코멘트 긁어오기
url = driver.current_url +"/comments"
print(url)

html = urlopen(url)
soup = BeautifulSoup(html, "html.parser")

soup.find_all('div','css-wnwcvo-Comment e1oskw6f0')
# Out:
# https://pedia.watcha.com/ko-KR/contents/m5GXgjp/comments
# [<div class="css-wnwcvo-Comment e1oskw6f0"><style data-emotion-css="6j702-TitleContainer">.css-6j702-TitleContainer{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;border-bottom:1px solid #e5e5e5;overflow:hidden;}</style><div class="css-6j702-TitleContainer e1oskw6f1"><style data-emotion-css="a2r0oi-ProfileBlock">.css-a2r0oi-ProfileBlock{-webkit-flex:1;-ms-flex:1;flex:1;font-size:17px;font-weight:400;-webkit-letter-spacing:-0.7px;-moz-letter-spacing:-0.7px;-ms-letter-spacing:-0.7px;letter-spacing:-0.7px;line-height:22px;overflow:hidden;}.css-a2r0oi-ProfileBlock > a{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#000;-webkit-text-decoration:none;text-decoration:none;}</style><div class="css-a2r0oi-ProfileBlock e1oskw6f2"><style data-emotion-css="1f9m1s4-StylelessLocalLink">.css-1f9m1s4-StylelessLocalLink{color:#000;-webkit-text-decoration:none;text-decoration:none;}.css-1f9m1s4-StylelessLocalLink:hover,.css-1f9m1s4-StylelessLocalLink:visited,.css-1f9m1s4-StylelessLocalLink:active{color:#000;}</style><a class="css-1f9m1s4-StylelessLocalLink e9fw3ul1" href="/ko-KR/users/nkPvrb8wrvgar" title="Jay Oh"><style data-emotion-css="1yi29vr-RoundedImageBlock-Self">.css-1yi29vr-RoundedImageBlock-Self{display:block;border:solid 1px rgba(0,0,0,0.08);border-radius:50%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:56px;height:56px;overflow:hidden;width:32px;height:32px;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;margin:11px 8px 11px 0;}</style><div class=" css-1yi29vr-RoundedImageBlock-Self e12ju1w01"><style data-emotion-css="1bfwwc2-ProfilePhotoImage">.css-1bfwwc2-ProfilePhotoImage{position:relative;z-index:1;background:url(https://dhgywazgeek0d.cloudfront.net/watcha/image/upload/c_fill,h_100,w_100/v1583633236/kw9yp7rnvqjni4vf3lsr.jpg) no-repeat center;background-size:cover;width:100%;height:100%;}</style><div class="css-1bfwwc2-ProfilePhotoImage e12ju1w00"></div></div><style data-emotion-css="1yetuql-Self">.css-1yetuql-Self{color:#1f1f1f;font-size:17px;font-weight:400;-webkit-letter-spacing:-0.7px;-moz-letter-spacing:-0.7px;-ms-letter-spacing:-0.7px;letter-spacing:-0.7px;line-height:22px;margin-bottom:2px;overflow:hidden;text-overflow:ellipsis;}</style><div class="css-1yetuql-Self e16ng6sd0"> <!-- -->Jay Oh</div></a></div><style data-emotion-css="1a97064-UserActionStatus">.css-1a97064-UserActionStatus{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background:#fff;color:#4a4a4a;font-size:14px;font-weight:400;-webkit-letter-spacing:-0.3px;-moz-letter-spacing:-0.3px;-ms-letter-spacing:-0.3px;letter-spacing:-0.3px;line-height:19px;box-sizing:border-box;min-width:55px;height:26px;padding:0 8px;border:1px solid #eaeaea;border-radius:13px;margin:15px 0 0 16px;}.css-1a97064-UserActionStatus > img{vertical-align:top;margin:0 3px 0 0;}</style><div class="css-1a97064-UserActionStatus e1oskw6f4"><img alt="star" height="16px" src="data:image/svg+xml;base64,..." width="16px"/><span>1.0</span></div></div><style data-emotion-css="103yoki-TextBlock">.css-103yoki-TextBlock{position:relative;height:120px;margin:12px 0 15px;height:auto;}</style><div class="css-103yoki-TextBlock e1oskw6f3"><style data-emotion-css="aintwb-Text">.css-aintwb-Text{white-space:pre-wrap;font-size:15px;font-weight:400;-webkit-letter-spacing:-0.2px;-moz-letter-spacing:-0.2px;-ms-letter-spacing:-0.2px;letter-spacing:-0.2px;line-height:24px;overflow:hidden;opacity:1;-webkit-transition:opacity 400ms;transition:opacity 400ms;-webkit-transit ...
#  Attention deficient spy debacle.</span></div></div><style data-emotion-css="3zteum-LikeReplyBlock">.css-3zteum-LikeReplyBlock{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#787878;font-size:14px;font-weight:400;-webkit-letter-spacing:-0.3px;-moz-letter-spacing:-0.3px;-ms-letter-spacing:-0.3px;letter-spacing:-0.3px;line-height:19px;height:44px;border-top:1px solid #e5e5e5;border-bottom:1px solid #e5e5e5;overflow:hidden;}</style><div class="css-3zteum-LikeReplyBlock e1xxz10x1"><style data-emotion-css="1h6wuq6-UIImg-LikeImage">.css-1h6wuq6-UIImg-LikeImage{display:inline-block;background:url(data:image/svg+xml;base64,...) no-repeat center;background-size:contain;width:18px;height:18px;margin:0 3px;}</style><span class="css-1h6wuq6-UIImg-LikeImage e1xxz10x2" height="18px" src="data:image/svg+xml;base64,..." width="18px"></span><em>39</em><style data-emotion-css="1nkne5l-UIImg-ReplyImage">.css-1nkne5l-UIImg-ReplyImage{display:inline-block;background:url(...) no-repeat center;background-size:contain;width:18px;height:18px;margin:0 3px 0 13px;}</style><span class="css-1nkne5l-UIImg-ReplyImage e1xxz10x3" height="18px" src="..." width="18px"></span><em>0</em></div><style data-emotion-css="yejb0s-UserActionBlock">.css-yejb0s-UserActionBlock{font-size:17px;font-weight:400;-webkit-letter-spacing:-0.7px;-moz-letter-spacing:-0.7px;-ms-letter-spacing:-0.7px;letter-spacing:-0.7px;line-height:22px;padding:9.5px 0;margin:0 -4px;}</style><div class="css-yejb0s-UserActionBlock e1xxz10x4"><style data-emotion-css="47hl39-StylelessButton-UserActionButton">.css-47hl39-StylelessButton-UserActionButton{background:none;padding:0;border:none;margin:0;cursor:pointer;color:#ff2f6e;font-size:17px;font-weight:400;-webkit-letter-spacing:-0.7px;-moz-letter-spacing:-0.7px;-ms-letter-spacing:-0.7px;letter-spacing:-0.7px;line-height:22px;padding:2px 8px;cursor:poiner;}.css-47hl39-StylelessButton-UserActionButton:focus{outline:none;}</style><button class="css-47hl39-StylelessButton-UserActionButton e1xxz10x5">좋아요</button></div></div>,
#  <div class="css-wnwcvo-Comment e1oskw6f0"><div class="css-6j702-TitleContainer e1oskw6f1"><div class="css-a2r0oi-ProfileBlock e1oskw6f2"><a class="css-1f9m1s4-StylelessLocalLink e9fw3ul1" href="/ko-KR/users/JZ4vBWYVW5RXO" title="Random cul"><div class=" css-1yi29vr-RoundedImageBlock-Self e12ju1w01"><style data-emotion-css="qflafv-ProfilePhotoImage">.css-qflafv-ProfilePhotoImage{position:relative;z-index:1;background:url(https://d3sz5r0rl9fxuc.cloudfront.net/assets/default/user/photo_file_name_small-bc8b334acec6a4e386249dedf9e763b5e6aff523fa85cc29211f22e6bed540df.jpg) no-repeat center;background-size:cover;width:100%;height:100%;}</style><div class="css-qflafv-ProfilePhotoImage e12ju1w00"></div></div><div class="css-1yetuql-Self e16ng6sd0"> <!-- -->Random cul<style data-emotion-css="1m9be8i-UIImg-SmallBadge">.css-1m9be8i-UIImg-SmallBadge{display:inline-block;background:url(data:image/svg+xml;base64,...) no-repeat center;background-size:contain;width:12px;height:12px;margin:0 0 0 3px;}</style><span class="css-1m9be8i-UIImg-SmallBadge e16ng6sd1" src="data:image/svg+xml;base64,..."></span></div></a></div><div class="css-1a97064-UserActionStatus e1oskw6f4"><img alt="star" height="16px" src="data:image/svg+xml;base64,..." width="16px"/><span>1.0</span></div></div><div class="css-103yoki-TextBlock e1oskw6f3"><div class="css-aintwb-Text e1xxz10x0"><span>낯익은 배우
#  낯익은 스토리
#  낯부끄러운 영화수준
#  옛날 성룡님 영화가 떠오르긴하나.
#  정신없고 황당하고 유치하고  ......</span></div></div><div class="css-3zteum-LikeReplyBlock e1xxz10x1"><span class="css-1h6wuq6-UIImg-LikeImage e1xxz10x2" height="18px" src="data:image/svg+xml;base64,..." width="18px"></span><em>37</em><span class="css-1nkne5l-UIImg-ReplyImage e1xxz10x3" height="18px" src="..." width="18px"></span><em>0</em></div><div class="css-yejb0s-UserActionBlock e1xxz10x4"><button class="css-47hl39-StylelessButton-UserActionButton e1xxz10x5">좋아요</button></div></div>,
#  <div class="css-wnwcvo-Comment e1oskw6f0"><div class="css-6j702-TitleContainer e1oskw6f1"><div class="css-a2r0oi-ProfileBlock e1oskw6f2"><a class="css-1f9m1s4-StylelessLocalLink e9fw3ul1" href="/ko-KR/users/Mr95nAN1jvZPG" title="뚱땡바리"><div class=" css-1yi29vr-RoundedImageBlock-Self e12ju1w01"><style data-emotion-css="sob4qo-ProfilePhotoImage">.css-sob4qo-ProfilePhotoImage{position:relative;z-index:1;background:url(https://images.watcha.net/user/558148/small/2a19a777b9daba4a344ab9f87ab36e22bcee3b05.jpg) no-repeat center;background-size:cover;width:100%;height:100%;}</style><div class="css-sob4qo-ProfilePhotoImage e12ju1w00"></div></div><div class="css-1yetuql-Self e16ng6sd0"> <!-- -->뚱땡바리</div></a></div><div class="css-1a97064-UserActionStatus e1oskw6f4"><img alt="star" height="16px" src="data:image/svg+xml;base64,..." width="16px"/><span>1.5</span></div></div><div class="css-103yoki-TextBlock e1oskw6f3"><div class="css-aintwb-Text e1xxz10x0"><span>영화보는 관객은 나혼자..
#  오랜만에 대관인데..
#
#  영화를 보면서도 이렇게 집중안되는
#  영화는 참으로 오랜만이다..</span></div></div><div class="css-3zteum-LikeReplyBlock e1xxz10x1"><span class="css-1h6wuq6-UIImg-LikeImage e1xxz10x2" height="18px" src="data:image/svg+xml;base64,..." width="18px"></span><em>10</em><span class="css-1nkne5l-UIImg-ReplyImage e1xxz10x3" height="18px" src="..." width="18px"></span><em>0</em></div><div class="css-yejb0s-UserActionBlock e1xxz10x4"><button class="css-47hl39-StylelessButton-UserActionButton e1xxz10x5">좋아요</button></div></div>]
